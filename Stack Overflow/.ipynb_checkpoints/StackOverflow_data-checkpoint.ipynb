# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
df.describe()
# Out:
#          Respondent  CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count  51392.000000        42695.000000     40376.000000  20600.000000
# mean   25696.500000            7.300574         6.957078      3.952282
# std    14835.736854            1.955444         2.167652      7.564722
# min        1.000000            0.000000         0.000000      0.000000
# 25%    12848.750000            6.000000         6.000000      1.000000
# 50%    25696.500000            8.000000         7.000000      1.000000
# 75%    38544.250000            9.000000         8.000000      4.000000
# max    51392.000000           10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               36592.000000   12891.000000     2566.000000
# mean                    8.429875   56298.480641    33142.220468
# std                     1.390635   39880.905277    30162.988829
# min                     0.000000       0.000000        0.000000
# ...

# %%
df.loc[:,df.dtypes=='float64']
# Out:
#        CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# 0                     NaN              NaN           0.0
# 1                     NaN              NaN           NaN
# 2                     8.0              9.0           NaN
# 3                     6.0              3.0           5.0
# 4                     6.0              8.0           NaN
# ...                   ...              ...           ...
# 51387                 7.0              3.0           5.0
# 51388                 NaN              NaN           NaN
# 51389                10.0             10.0           NaN
# 51390                 6.0              7.0           1.0
# 51391                 8.0              8.0           2.0
#
#        StackOverflowSatisfaction    Salary  ExpectedSalary
# 0                            9.0       NaN             NaN
# 1                            8.0       NaN         37500.0
# 2                            8.0  113750.0             NaN
# ...

# %%
from itertools import count

# %%
df[df.loc[:,df.dtypes=='object'].isna()==True].any()
# Out:
# Respondent              False
# Professional            False
# ProgramHobby            False
# Country                 False
# University              False
#                         ...
# QuestionsInteresting    False
# QuestionsConfusing      False
# InterestedAnswers       False
# Salary                  False
# ExpectedSalary          False
# Length: 154, dtype: bool

# %%
df.iloc[:,[40]
# Out:
# 0        Strongly agree
# 1                   NaN
# 2        Somewhat agree
# 3                 Agree
# 4                   NaN
#               ...
# 51387    Strongly agree
# 51388               NaN
# 51389               NaN
# 51390    Strongly agree
# 51391               NaN
# Name: InvestTimeTools, Length: 51392, dtype: object

# %%
df.loc[:,'CompanySize':'CareerSatisfaction']
# Out:
#                     CompanySize  \
# 0                           NaN
# 1            20 to 99 employees
# 2      10,000 or more employees
# 3      10,000 or more employees
# 4            10 to 19 employees
# ...                         ...
# 51387      100 to 499 employees
# 51388      100 to 499 employees
# 51389        10 to 19 employees
# 51390   Fewer than 10 employees
# 51391  10,000 or more employees
#
#                                              CompanyType      YearsProgram  \
# 0                                                    NaN      2 to 3 years
# 1      Privately-held limited company, not in startup...     9 to 10 years
# 2                            Publicly-traded corporation  20 or more years
# 3      Non-profit/non-governmental organization or pr...    14 to 15 years
# 4      Privately-held limited company, not in startup...  20 or more years
# ...                                                  ...               ...
# ...

# %%
df.loc[:,'CareerSatisfaction':]
# Out:
#        CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe  \
# 0                     NaN              NaN           NaN             NaN
# 1                     NaN              NaN           NaN             NaN
# 2                     8.0              9.0           NaN             NaN
# 3                     6.0              3.0           NaN             NaN
# 4                     6.0              8.0           NaN             NaN
# ...                   ...              ...           ...             ...
# 51387                 7.0              3.0           NaN             NaN
# 51388                 NaN              NaN           NaN             NaN
# 51389                10.0             10.0           NaN             NaN
# 51390                 6.0              7.0           NaN             NaN
# 51391                 8.0              8.0           NaN             NaN
#
#       ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills  \
# ...

# %%
df.loc[:,'ExCoderActive':]
# Out:
#       ExCoderActive                  PronounceGIF  ProblemSolving  \
# 0               NaN  With a soft "g," like "jiff"  Strongly agree
# 1               NaN  With a hard "g," like "gift"             NaN
# 2               NaN  With a hard "g," like "gift"  Strongly agree
# 3               NaN  With a soft "g," like "jiff"  Strongly agree
# 4               NaN  With a soft "g," like "jiff"             NaN
# ...             ...                           ...             ...
# 51387           NaN  With a soft "g," like "jiff"  Strongly agree
# 51388           NaN  With a soft "g," like "jiff"             NaN
# 51389           NaN  With a soft "g," like "jiff"             NaN
# 51390           NaN  With a soft "g," like "jiff"  Strongly agree
# 51391           NaN  With a hard "g," like "gift"             NaN
#
#        BuildingThings LearningNewTech      BoringDetails     JobSecurity  \
# 0      Strongly agree           Agree           Disagree  Strongly agree
# ...

# %%
df.loc[:,'FriendsDevelopers':]
# Out:
#        FriendsDevelopers   RightWrongWay UnderstandComputers     SeriousWork  \
# 0               Disagree  Somewhat agree            Disagree  Strongly agree
# 1                    NaN             NaN                 NaN             NaN
# 2         Somewhat agree        Disagree            Disagree           Agree
# 3                  Agree  Somewhat agree   Strongly disagree  Strongly agree
# 4                    NaN             NaN                 NaN             NaN
# ...                  ...             ...                 ...             ...
# 51387  Strongly disagree        Disagree               Agree           Agree
# 51388                NaN             NaN                 NaN             NaN
# 51389                NaN             NaN                 NaN             NaN
# 51390           Disagree           Agree   Strongly disagree  Strongly agree
# 51391                NaN             NaN                 NaN             NaN
#
# ...

# %%
df.loc[:,'ChangeWorld':]
# Out:
#              ChangeWorld                                   JobSeekingStatus  \
# 0                  Agree  I'm not actively looking, but I am open to new...
# 1                    NaN                                                NaN
# 2                  Agree                                                NaN
# 3                  Agree                    I am actively looking for a job
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 51387     Somewhat agree                    I am actively looking for a job
# 51388                NaN                                                NaN
# 51389                NaN                                                NaN
# 51390  Strongly disagree  I'm not actively looking, but I am open to new...
# 51391                NaN  I'm not actively looking, but I am open to new...
#
# ...

# %%
df.loc[:,'AssessJobProjects':]
# Out:
#         AssessJobProjects AssessJobCompensation     AssessJobOffice  \
# 0          Very important             Important      Very important
# 1                     NaN                   NaN                 NaN
# 2                     NaN                   NaN                 NaN
# 3          Very important             Important      Very important
# 4                     NaN                   NaN                 NaN
# ...                   ...                   ...                 ...
# 51387  Not very important        Very important  Somewhat important
# 51388                 NaN                   NaN                 NaN
# 51389                 NaN                   NaN                 NaN
# 51390           Important             Important           Important
# 51391      Very important        Very important      Very important
#
#          AssessJobCommute       AssessJobRemote    AssessJobLeaders  \
# 0          Very important        Very important      Very important
# ...

# %%
df.loc[:,'AssessJobFinances':]
# Out:
#         AssessJobFinances                                  ImportantBenefits  \
# 0      Somewhat important   Stock options; Vacation/days off; Remote options
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3          Very important  Stock options; Annual bonus; Health benefits; ...
# 4                     NaN                                                NaN
# ...                   ...                                                ...
# 51387           Important  Vacation/days off; Health benefits; Private of...
# 51388                 NaN                                                NaN
# 51389                 NaN                                                NaN
# 51390  Somewhat important  Equipment; Education sponsorship; Expected wor...
# 51391  Somewhat important  Annual bonus; Vacation/days off; Health benefi...
#
# ...
